# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xlwt
import math
import random

from xlwt import Workbook

#------Değiştirilecek yerler------

Starting_WaveLength = 380   #Başlangıç Dalga Boyu Uzunluk Değeri
Ending_WaveLength = 780     #Bitiş Dalga Boyu Uzunluk Değeri
DalgaBoyları_Fark = 5       #Ardışık iki Dalga Arasındaki Sabit Farki Örneğin 380 385 390 veya 380 381 382... gibi

DataSayısı = 11             #input Excel Tabloasındaki kullanacağınız Data Sayınız

#Kullanmak istediğiniz Dataların isimlerinin girildiği yer.Çok uzun olmamalı.DataSayısı ile aynı sayıda isim girilmeli.
DatasNames = ["FiK","FiR","Rr","Sxi","Sai","Sbi","Sei","Syi","Ski","Sni","Ssi"]

formul_no = 2 #Hangi formul denklemi ve input Excel dosyası kullanılacaksa ona göre girilmeli.Örneğin input_1 input_2 gibi

Iteration_Number = 1000  #Monte Carlo İterasyon Sayısı

#---------------------------------




Sum_WaveLength = int((Ending_WaveLength - Starting_WaveLength+DalgaBoyları_Fark)/DalgaBoyları_Fark)
print("Dalga Boyu Sayısı:"+str(Sum_WaveLength))

Input_Datas_Values=[] #input Excel tablosundan verilerin çekilip atıldığı Liste
Datas_List=[] #Dataların random üretelip her bir datanın Verilerinin atıldığı List.Liste içinde Liste barındırmaktadır.
for i in range(0,DataSayısı):
    list = []
    Datas_List.append(list)

sum_of_sample_List=[] #for Standart Dev calculate

#Bunları tek bir fonksiyonda yapmalısın.Fazladan satır olmasın
for i in range(0,Sum_WaveLength):
    liste = []
    sum_of_sample_List.append(liste)

wb = Workbook() #Başlangıç output excel dosyalarının oluşturulması
tiles = wb.add_sheet('output2')
tiles2 = wb.add_sheet('output1')
tiles2.write(0,0,'Iteration Number') 
tiles2.write(0,1,Iteration_Number)

from openpyxl import Workbook,load_workbook #En tepede tanımlandığında error verdiği için arada tanımladım.
wB= load_workbook("input_"+str(formul_no)+".xlsx")#Uzantısının xlsx olmalı.input dosyası okunur ve wS Workbook'una atılır
wS = wB.active
wS = wB["INPUT"]
ColumnNames = ['Wave Length','Average', 'Standart Deviation']
for col_num,data in enumerate(ColumnNames):
    tiles2.write(1,col_num,data)

#Bu değişkenlerde ise DataSayımız kadar datamızın ortalama değerlerini ve standart sapmalarını yazıcaz.
#Tek olanlar ortalama çift olanlar standart sapmayı veriyor.   
AVG_STD_of_DATA=[]
AVG_STD_of_Result=[]

KorelasyonaMatrix = []
TempMatrix = [] #Gerekli Matrisi kullanmak için kullanacağız
for i in range(0,Sum_WaveLength):
    List = []
    KorelasyonaMatrix.append(List)
    for j in range(0,DataSayısı):
        SutunList = []
        KorelasyonaMatrix[i].append(SutunList)
        
    TempSutunList = []
    TempMatrix.append(TempSutunList)

print("Temp Matrix:\n"+str(TempMatrix))        
        
def Data_Find_AVG(Data):
    
    ortalama=np.mean(Data)
    return ortalama

def Data_Find_STD(Data):
   
    standartS=np.std(Data)
    return standartS
def get_rand_values(avg,std):
    
    result=np.random.normal(avg,abs(std),1)#Belki bu da örnek sayısına göre değişebilir.Zamanda oynama olarak.
    ortalama=np.mean(result)
    return ortalama

def formul(DL):
    
    #Buradaki datalarımızın sırasının ne olduğu DatasNames sırasındaki data isimleri gibi yazılmalı.
    #Sonradan eklenilmesi gereken formüller yeni bir elif altında eklenilmeli ve oluşturulmalı.
    
    if formul_no == 1:                                                                                                                                                                                
        result = (DL[0]+DL[5])*(DL[4]/DL[1])*(DL[2]/DL[3])*(1+DL[6]+DL[7]+DL[12]+DL[8]+DL[9]+DL[10]+DL[11])
    elif formul_no == 2:
        result =(DL[0]/DL[1])*DL[4]*(DL[2]*DL[3]*DL[5]*DL[6]*DL[7]*DL[8]*DL[9]*DL[10])
    
    return result

#output2   
def CreateExcel():#Create Excel Titles and Write First Values of Datas
    
    ColumnNames = ['Wave Length']
    for i in range(0,DataSayısı):
        ColumnNames.append('Average '+DatasNames[i])
        ColumnNames.append('Standart Dev '+DatasNames[i])
    
    for col_num,data in enumerate(ColumnNames):
        tiles.write(0,col_num,data)
        
    tiles.write(1,0,Starting_WaveLength)
    
    for col_num, data in enumerate(AVG_STD_of_DATA):
        tiles.write(1, col_num+1, data)
    
    wb.save('OUTPUT_'+str(Iteration_Number)+'_'+str(formul_no)+'.xls')

#output2      
def AddToExcel(DalgaBoyuIndexLast,count):#add to output excel 
    
    tiles.write(count,0,DalgaBoyuIndexLast)
    
    for col_num,data in enumerate(AVG_STD_of_DATA):
        tiles.write(count,col_num+1,data)
    
    wb.save('OUTPUT_'+str(Iteration_Number)+'_'+str(formul_no)+'.xls')
    
#output1    
def Output1Excel(DalgaBoyuIndex,count,avg,std):
    
    List=[avg,std]
    tiles2.write(count+1,0,DalgaBoyuIndex)
    for col_num,data in enumerate(List):
        tiles2.write(count+1,col_num+1,data)
        
    wb.save('OUTPUT_'+str(Iteration_Number)+'_'+str(formul_no)+'.xls')  

def DefineCorrMatrix(Matrix):
    #Array tipinde Matrix olmalı.Frame olarak değil.
    temp = np.corrcoef(Matrix)
    return np.array(temp)    

def corrPlot(Matrix):

    fig=plt.figure()
    subplot=fig.add_subplot(111)
    cax=subplot.imshow(Matrix,vmin=-1,vmax=1,interpolation ='nearest',cmap="jet",origin="lower")
    fig.colorbar (cax, ticks=[-1,-0.5,0,0.5,1])
    plt.show()

def monte_carlo(IterationNum,DalgaBoyuIndexLast,count):
    
    #count yazılacağı index değerine karşılık geliyor.
    
    sum_of_samples=0.0
    
    for i in range(IterationNum):
        
        Indexsayac=0
        mean_data=[]
        
        for i in range(0,DataSayısı):#random dataların oluşturulup atandığı yer.
            mean_data.append(get_rand_values(Input_Datas_Values[Indexsayac],Input_Datas_Values[Indexsayac+1]))
            KorelasyonaMatrix[count-1][i].append(mean_data[i])
            Datas_List[i].append(mean_data[i]) 
            Indexsayac+=2
        
        sum_of_sample_List[count-1].append(formul(mean_data)) #main döngsünde kullanılıyor.
        
        sum_of_samples+=formul(mean_data)
        
    print("------")
    print(sum_of_samples)
    
    #Bu bu değişkenlerde ise monte-carlo fonksiyonun içerisinde yaparak ortalama ve std buluyoruz.
    for k in range(0,DataSayısı):
        AVG_STD_of_DATA.append(Data_Find_AVG(Datas_List[k]))
        AVG_STD_of_DATA.append(Data_Find_STD(Datas_List[k]))
    
    if count == 1: #İlk kez döngüde dönüyorsa output2 Exceli oluştur.
        CreateExcel()
    else:
        AddToExcel(DalgaBoyuIndexLast,count)
        
    return float(sum_of_samples/IterationNum)

#-----MAIN-----

#Starting_WaveLength'in Excel de olup olmadığına bakılır ve hangi excel'deki hangi satıra denk geldiğini bulunur.
StartingRow = 1
count = 1
for satır in range(2,(Sum_WaveLength+1)*10):#+1 yapma sebebim Dalga Boyu Sayısının 1 fazla excel'de satıra denk gelmesi.
    if wS.cell(satır,1).value == Starting_WaveLength:
        print("StartingRow değişmektedir.")
        StartingRow = satır
        break
print("\nBaşlangıç Satır Indexi:"+str(StartingRow)+"\n")

for DalgaBoyuIndex in range(Starting_WaveLength,Ending_WaveLength+DalgaBoyları_Fark,DalgaBoyları_Fark):
    
    print("Dalga Boyu")
    print(DalgaBoyuIndex)
    print("count")
    print(count)
    
    #Dosyadan okuma işlemi.input dosyasından hücre hücre okuma işlemi
    for sutun in range(2,DataSayısı*2+2):#DataSayısı*2+2 de çalışıyor döngü tam olarak.2'den başladığı için
        Input_Datas_Values.append(float(wS.cell(StartingRow,sutun).value))    
    print("\nInput Data Values:\n"+str(Input_Datas_Values))
    
    Monte_Avg=monte_carlo(Iteration_Number,DalgaBoyuIndex,count)
    AVG_STD_of_Result.append(Monte_Avg)
    AVG_STD_of_Result.append(Data_Find_STD(sum_of_sample_List[count-1]))
    Output1Excel(DalgaBoyuIndex,count,AVG_STD_of_Result[len(AVG_STD_of_Result)-2],AVG_STD_of_Result[len(AVG_STD_of_Result)-1])
         
    for i in range(0,DataSayısı):
        Datas_List[i].clear()
    
    print("******")
    print(AVG_STD_of_DATA)
    AVG_STD_of_DATA.clear()
    Input_Datas_Values.clear()
    count+=1
    StartingRow+=1
    
print("Işık Akısının ortalama değeri:")
print(Monte_Avg)
print("*****")
print(AVG_STD_of_DATA)

#Korelasyon için diğer kısımlar

KorelasyonaArray = np.array(KorelasyonaMatrix)
print("KorelasyonaArray:"+str(KorelasyonaArray.shape))

for i in range(0,DataSayısı):
    for k in range(0,Sum_WaveLength):
        for j in range(0,Iteration_Number):
            TempMatrix[k].append(KorelasyonaMatrix[k][i][j])
            
    TempDizi = np.array(TempMatrix)
    print("TempMatrix:\n"+str(TempDizi))       
    print("Boyut:"+str(TempDizi.shape))
    
    print("\n*******\n "+str(i+1)+".data'nın Korelasyon Kat sayısı ve görselleştirilmesi:\n")
    CorrTemp = DefineCorrMatrix(TempDizi)
    print("Korelasyon Kat Sayı Matrisi:\n"+str(CorrTemp))
    print("Boyut:"+str(CorrTemp.shape))
   
    corrPlot(CorrTemp)
    
    #Burada Korelasyon İşlemini ve Görselleştirmesini yapman gerekiyor.Bunun üstünde
    TempMatrix.clear()
    for satir in range(0,Sum_WaveLength):#Bunu bir fonksiyon içerisinde yazarsan senin için daha iyi olur.Diğerlerinide ona göre yaparsın.
        TempSutunList = []
        TempMatrix.append(TempSutunList)
        
KorelasyonSonuçlar_Matrix = np.array(sum_of_sample_List)
print("Sonuçlar Matrix:\n"+str(KorelasyonSonuçlar_Matrix))
print("Boyut:"+str(KorelasyonSonuçlar_Matrix.shape))

Result_Corr = DefineCorrMatrix(KorelasyonSonuçlar_Matrix)
print("\nSonuçlar Korelasyon Kat Sayılar Matrisi:\n"+str(Result_Corr))
print("Boyut:"+str(Result_Corr.shape))

corrPlot(Result_Corr)

#--------------
# Out:
# Dalga Boyu Sayısı:81
# Temp Matrix:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# StartingRow değişmektedir.
#
# Başlangıç Satır Indexi:2
#
# Dalga Boyu
# 380
# count
# 1
#
# Input Data Values:
# [1.000878783603614, 0.000466666666666667, 1.0, 0.000466666666666667]
# ------
# 2000.8951466072313
# ******
# [1.0009031383920042, 0.00047770249641207967, 0.999992008215228, 0.00047074382758230144]
# Dalga Boyu
# 385
# count
# 2
#
# Input Data Values:
# [0.9952915200799677, 0.000466666666666667, 0.994240935603086, 0.000466666666666667]
# ------
# 1989.5266316252143
# ******
# [0.9952631057354829, 0.0004532915550553377, 0.9942635258897294, 0.00046369393724974374]
# Dalga Boyu
# 390
# count
# 3
#
# Input Data Values:
# [0.9880411108716877, 0.000466666666666667, 0.9907625154768301, 0.000466666666666667]
# ------
# 1978.8363444652261
# ******
# [0.9880603203808187, 0.0004798521314562832, 0.9907760240844079, 0.0004573388004664701]
# Dalga Boyu
# 395
# count
# 4
#
# Input Data Values:
# [0.9819484036702767, 0.000466666666666667, 0.9887281001949618, 0.000466666666666667]
# ------
# 1970.6860135149511
# ******
# [0.9819590387759567, 0.0004816959235329112, 0.9887269747389921, 0.0004616429265088452]
# Dalga Boyu
# 400
# count
# 5
#
# Input Data Values:
# [0.9824535779646525, 0.000466666666666667, 0.9983877809224032, 0.000466666666666667]
# ------
# 1980.8439704186512
# ******
# [0.9824481902258387, 0.0004645552753578984, 0.9983957801928106, 0.00048064180786687585]
# Dalga Boyu
# 405
# count
# 6
#
# Input Data Values:
# [0.9852080365671806, 0.000466666666666667, 0.9949157366452924, 0.000466666666666667]
# ------
# 1980.1045651803934
# ******
# [0.9851987932178091, 0.0004746806588925365, 0.9949057719625838, 0.000481736205790003]
# Dalga Boyu
# 410
# count
# 7
#
# Input Data Values:
# [0.9889828331785331, 0.000466666666666667, 0.9976608851755404, 0.000466666666666667]
# ------
# 1986.6451725569045
# ******
# [0.9889736407237626, 0.0004622706012259973, 0.9976715318331456, 0.00046906323866064727]
# Dalga Boyu
# 415
# count
# 8
#
# Input Data Values:
# [0.9909267670859185, 0.000466666666666667, 0.9976808929196519, 0.000466666666666667]
# ------
# 1988.5854766995474
# ******
# [0.99093343318086, 0.0004600795960705726, 0.9976520435186853, 0.00047621762117339367]
# Dalga Boyu
# 420
# count
# 9
#
# Input Data Values:
# [0.9908160645565016, 0.000466666666666667, 0.9964393939908617, 0.000466666666666667]
# ------
# 1987.2487936167818
# ******
# [0.9908211692811376, 0.0004717969905122805, 0.9964276243356435, 0.0004620874894992212]
# Dalga Boyu
# 425
# count
# 10
#
# Input Data Values:
# [0.9897221103233806, 0.000466666666666667, 0.9954297940986541, 0.000466666666666667]
# ------
# 1985.12832222369
# ******
# [0.9896984202838227, 0.000471296075065699, 0.9954299019398664, 0.0004695541556911176]
# Dalga Boyu
# 430
# count
# 11
#
# Input Data Values:
# [0.9901013723287699, 0.000466666666666667, 0.9966474918554659, 0.000466666666666667]
# ------
# 1986.7606379221118
# ******
# [0.9901111535132695, 0.0004622191037755623, 0.996649484408843, 0.00046431248647318843]
# Dalga Boyu
# 435
# count
# 12
#
# Input Data Values:
# [0.9910136996237044, 0.000466666666666667, 0.9977197003390887, 0.000466666666666667]
# ------
# 1988.756623940628
# ******
# [0.9910292744465735, 0.00047245623240002273, 0.9977273494940544, 0.00046980343885049373]
# Dalga Boyu
# 440
# count
# 13
#
# Input Data Values:
# [0.9908055121895557, 0.000466666666666667, 0.997192665376358, 0.000466666666666667]
# ------
# 1987.9805214973803
# ******
# [0.990789143338573, 0.0004869936957845982, 0.9971913781588062, 0.0004772954172410377]
# Dalga Boyu
# 445
# count
# 14
#
# Input Data Values:
# [0.9886887186566636, 0.000466666666666667, 0.9951056686888498, 0.000466666666666667]
# ------
# 1983.8039148806085
# ******
# [0.9886935845123009, 0.00045886268547228975, 0.995110330368308, 0.00046041908202952987]
# Dalga Boyu
# 450
# count
# 15
#
# Input Data Values:
# [0.9853116874805585, 0.000466666666666667, 0.9927328459912802, 0.000466666666666667]
# ------
# 1978.0769496734524
# ******
# [0.9853523455988893, 0.0004763289681973176, 0.9927246040745599, 0.0004516159942265821]
# Dalga Boyu
# 455
# count
# 16
#
# Input Data Values:
# [0.9826256633579967, 0.000466666666666667, 0.9915711651052443, 0.000466666666666667]
# ------
# 1974.164545040816
# ******
# [0.9825974806302906, 0.0004646739221787251, 0.9915670644105262, 0.0004510873765926232]
# Dalga Boyu
# 460
# count
# 17
#
# Input Data Values:
# [0.9827849730511773, 0.000466666666666667, 0.9928963704150647, 0.000466666666666667]
# ------
# 1975.6565694117207
# ******
# [0.9827964895880617, 0.0004601538816783689, 0.9928600798236558, 0.0004709516179721407]
# Dalga Boyu
# 465
# count
# 18
#
# Input Data Values:
# [0.9847978904412038, 0.000466666666666667, 0.9949731423502891, 0.000466666666666667]
# ------
# 1979.8159671725587
# ******
# [0.9848170968723957, 0.00045112856734787237, 0.9949988703001617, 0.00047071535602449]
# Dalga Boyu
# 470
# count
# 19
#
# Input Data Values:
# [0.9876145626935409, 0.000466666666666667, 0.99710185456766, 0.000466666666666667]
# ------
# 1984.7122950720327
# ******
# [0.9876176091392699, 0.00046005222180890877, 0.997094685932763, 0.00046050860980584996]
# Dalga Boyu
# 475
# count
# 20
#
# Input Data Values:
# [0.9893246679386176, 0.000466666666666667, 0.9975348958776525, 0.000466666666666667]
# ------
# 1986.861441258938
# ******
# [0.9893273026845141, 0.0004595656128178293, 0.9975341385744239, 0.00045929693962034116]
# Dalga Boyu
# 480
# count
# 21
#
# Input Data Values:
# [0.9890085714029276, 0.000466666666666667, 0.996281635079476, 0.000466666666666667]
# ------
# 1985.3293209214391
# ******
# [0.9890273999764235, 0.0004755094417845303, 0.9963019209450162, 0.0004537507362388259]
# Dalga Boyu
# 485
# count
# 22
#
# Input Data Values:
# [0.9869209283362703, 0.000466666666666667, 0.9943767666867132, 0.000466666666666667]
# ------
# 1981.3150127724277
# ******
# [0.9869201873553657, 0.0004730667001252381, 0.9943948254170639, 0.000461395659825177]
# Dalga Boyu
# 490
# count
# 23
#
# Input Data Values:
# [0.985621251823329, 0.000466666666666667, 0.9944001276896609, 0.000466666666666667]
# ------
# 1980.0330655353134
# ******
# [0.9856201572133523, 0.00047211333037937574, 0.9944129083219614, 0.00045681617284553966]
# Dalga Boyu
# 495
# count
# 24
#
# Input Data Values:
# [0.9860311294209324, 0.000466666666666667, 0.9957144616388169, 0.000466666666666667]
# ------
# 1981.7334353195404
# ******
# [0.9860031856387905, 0.0004661595043934173, 0.9957302496807493, 0.00047290131513886766]
# Dalga Boyu
# 500
# count
# 25
#
# Input Data Values:
# [0.9886031345123494, 0.000466666666666667, 0.9982962528976117, 0.000466666666666667]
# ------
# 1986.9018098509807
# ******
# [0.9885945446694996, 0.00043943648537552485, 0.9983072651814837, 0.0004678346418614926]
# Dalga Boyu
# 505
# count
# 26
#
# Input Data Values:
# [0.9903630577821907, 0.000466666666666667, 0.9986553376970577, 0.000466666666666667]
# ------
# 1989.022674811914
# ******
# [0.990374415605639, 0.0004734957025932398, 0.998648259206273, 0.00044698575931122436]
# Dalga Boyu
# 510
# count
# 27
#
# Input Data Values:
# [0.9908825182227545, 0.000466666666666667, 0.998070141298847, 0.000466666666666667]
# ------
# 1988.979981624177
# ******
# [0.9909013378604884, 0.0004887125791270381, 0.9980786437636897, 0.0004565966100936779]
# Dalga Boyu
# 515
# count
# 28
#
# Input Data Values:
# [0.991611213106364, 0.000466666666666667, 0.9985134957791966, 0.000466666666666667]
# ------
# 1990.1328795930963
# ******
# [0.9916024578767038, 0.000459533909605058, 0.9985304217163911, 0.00047463862550483054]
# Dalga Boyu
# 520
# count
# 29
#
# Input Data Values:
# [0.9932716363048457, 0.000466666666666667, 0.9998144710549831, 0.000466666666666667]
# ------
# 1993.0625722016614
# ******
# [0.9932789752465785, 0.00046335831254555295, 0.9997835969550831, 0.000461661184226469]
# Dalga Boyu
# 525
# count
# 30
#
# Input Data Values:
# [0.9953762367664332, 0.000466666666666667, 1.0008631482762635, 0.000466666666666667]
# ------
# 1996.2967972910503
# ******
# [0.9953949229166011, 0.0004726110272552337, 1.0009018743744469, 0.0004673013039417366]
# Dalga Boyu
# 530
# count
# 31
#
# Input Data Values:
# [0.9974680273394745, 0.000466666666666667, 1.0014545006434465, 0.000466666666666667]
# ------
# 1998.9613621172593
# ******
# [0.99750039393737, 0.0004453046915151095, 1.0014609681798894, 0.00048081025556609387]
# Dalga Boyu
# 535
# count
# 32
#
# Input Data Values:
# [0.9985323350749729, 0.000466666666666667, 1.0007974056472888, 0.000466666666666667]
# ------
# 1999.333281889436
# ******
# [0.9985246099736491, 0.00046065769072562357, 1.0008086719157872, 0.0004589707541127215]
# Dalga Boyu
# 540
# count
# 33
#
# Input Data Values:
# [0.9992277664814204, 0.000466666666666667, 1.000578114565576, 0.000466666666666667]
# ------
# 1999.7941796923537
# ******
# [0.9992378674847799, 0.0004717148752582008, 1.0005563122075753, 0.0004765686915316169]
# Dalga Boyu
# 545
# count
# 34
#
# Input Data Values:
# [0.9997744070129375, 0.000466666666666667, 1.000512784815505, 0.000466666666666667]
# ------
# 2000.291730992065
# ******
# [0.9997739592701439, 0.00044866519487978175, 1.0005177717219187, 0.00047303970538245814]
# Dalga Boyu
# 550
# count
# 35
#
# Input Data Values:
# [1.0003133722668343, 0.000466666666666667, 1.000561015788881, 0.000466666666666667]
# ------
# 2000.8716005043188
# ******
# [1.0003013517795596, 0.0004698140746297038, 1.0005702487247594, 0.00046830488052060175]
# Dalga Boyu
# 555
# count
# 36
#
# Input Data Values:
# [1.0008150316982085, 0.000466666666666667, 1.000561344303057, 0.000466666666666667]
# ------
# 2001.3793242920838
# ******
# [1.0008130115037892, 0.0004640931790068002, 1.0005663127882936, 0.00047597064267846414]
# Dalga Boyu
# 560
# count
# 37
#
# Input Data Values:
# [1.00133342407274, 0.000466666666666667, 1.0006023622273172, 0.000466666666666667]
# ------
# 2001.9589520630154
# ******
# [1.001351771438327, 0.00047458529541646584, 1.0006071806246857, 0.00046934623920973306]
# Dalga Boyu
# 565
# count
# 38
#
# Input Data Values:
# [1.0018345347144082, 0.000466666666666667, 1.0005944726532234, 0.000466666666666667]
# ------
# 2002.435796616318
# ******
# [1.001830138907621, 0.00045743718851397883, 1.0006056577086988, 0.0004470157595072662]
# Dalga Boyu
# 570
# count
# 39
#
# Input Data Values:
# [1.0023590105494387, 0.000466666666666667, 1.000613817428998, 0.000466666666666667]
# ------
# 2002.978332669513
# ******
# [1.0023523926441322, 0.00047705278998690635, 1.0006259400253816, 0.0004534776459933515]
# Dalga Boyu
# 575
# count
# 40
#
# Input Data Values:
# [1.0028805232061715, 0.000466666666666667, 1.0005914841310557, 0.000466666666666667]
# ------
# 2003.420391451597
# ******
# [1.002851626160795, 0.00046571039630583937, 1.0005687652908006, 0.0004656896116957589]
# Dalga Boyu
# 580
# count
# 41
#
# Input Data Values:
# [1.0034393193555626, 0.000466666666666667, 1.0005947370903947, 0.000466666666666667]
# ------
# 2004.0367867188631
# ******
# [1.0034321966631712, 0.00048190955481094175, 1.0006045900556906, 0.0004619024435540698]
# Dalga Boyu
# 585
# count
# 42
#
# Input Data Values:
# [1.0039376983614179, 0.000466666666666667, 1.0004730143413518, 0.000466666666666667]
# ------
# 2004.384839565238
# ******
# [1.0039320145689803, 0.000467228652944627, 1.000452824996255, 0.0004504846232794166]
# Dalga Boyu
# 590
# count
# 43
#
# Input Data Values:
# [1.0045910000596054, 0.000466666666666667, 1.0005672412233968, 0.000466666666666667]
# ------
# 2005.1607991620308
# ******
# [1.0045859424802883, 0.00045559694799892367, 1.0005748566817454, 0.00045621872521194463]
# Dalga Boyu
# 595
# count
# 44
#
# Input Data Values:
# [1.0050452724801022, 0.000466666666666667, 1.0002501279988703, 0.000466666666666667]
# ------
# 2005.3038061719446
# ******
# [1.0050505959972447, 0.000472329013013806, 1.0002532101746995, 0.00044259566554382665]
# Dalga Boyu
# 600
# count
# 45
#
# Input Data Values:
# [1.0057086513704725, 0.000466666666666667, 1.0003699949074816, 0.000466666666666667]
# ------
# 2006.0599897825364
# ******
# [1.0056786246056377, 0.00044869903482895737, 1.0003813651769007, 0.000461522716974527]
# Dalga Boyu
# 605
# count
# 46
#
# Input Data Values:
# [1.0062878112520586, 0.000466666666666667, 1.0001236148604593, 0.000466666666666667]
# ------
# 2006.3908441756373
# ******
# [1.006276355701053, 0.00045547562233630494, 1.000114488474586, 0.00044213282769618495]
# Dalga Boyu
# 610
# count
# 47
#
# Input Data Values:
# [1.0068552709889222, 0.000466666666666667, 0.9999419849334239, 0.000466666666666667]
# ------
# 2006.760672549252
# ******
# [1.0068379868268225, 0.0004515289339640307, 0.9999226857224303, 0.00048152237671276164]
# Dalga Boyu
# 615
# count
# 48
#
# Input Data Values:
# [1.007553590578344, 0.000466666666666667, 0.9998941702654759, 0.000466666666666667]
# ------
# 2007.4324024673099
# ******
# [1.0075489586479744, 0.0004559047057114471, 0.9998834438193366, 0.00047589697484337644]
# Dalga Boyu
# 620
# count
# 49
#
# Input Data Values:
# [1.0080793381040947, 0.000466666666666667, 0.9994524482906502, 0.000466666666666667]
# ------
# 2007.5422244650292
# ******
# [1.0080871718054203, 0.00048343444677979917, 0.9994550526596109, 0.0004723261079888541]
# Dalga Boyu
# 625
# count
# 50
#
# Input Data Values:
# [1.0087983137126253, 0.000466666666666667, 0.9994313379205976, 0.000466666666666667]
# ------
# 2008.2315073805516
# ******
# [1.0087925693535484, 0.00047086666385872224, 0.9994389380270027, 0.00046850939063443174]
# Dalga Boyu
# 630
# count
# 51
#
# Input Data Values:
# [1.0093080436204158, 0.000466666666666667, 0.9988771734404344, 0.000466666666666667]
# ------
# 2008.148406376646
# ******
# [1.0092922938306739, 0.0004530946485941696, 0.9988561125459726, 0.0004752466972292367]
# Dalga Boyu
# 635
# count
# 52
#
# Input Data Values:
# [1.009820483231838, 0.000466666666666667, 0.998602555974866, 0.000466666666666667]
# ------
# 2008.4204193086532
# ******
# [1.0098290081427332, 0.00048742004023800316, 0.9985914111659199, 0.0004432914887525575]
# Dalga Boyu
# 640
# count
# 53
#
# Input Data Values:
# [1.0105039446014943, 0.000466666666666667, 0.998485652743891, 0.000466666666666667]
# ------
# 2008.9807893956395
# ******
# [1.0104963983164224, 0.0004620304572525007, 0.9984843910792167, 0.0004692985824285839]
# Dalga Boyu
# 645
# count
# 54
#
# Input Data Values:
# [1.0109642430551635, 0.000466666666666667, 0.997821228206514, 0.000466666666666667]
# ------
# 2008.7850355200394
# ******
# [1.0109544057339255, 0.0004542299066617772, 0.9978306297861143, 0.00047463850126864865]
# Dalga Boyu
# 650
# count
# 55
#
# Input Data Values:
# [1.0114325789232175, 0.000466666666666667, 0.9975014264358815, 0.000466666666666667]
# ------
# 2008.931092595111
# ******
# [1.0114247062053454, 0.00047321889089195767, 0.9975063863897657, 0.0004600214942075743]
# Dalga Boyu
# 655
# count
# 56
#
# Input Data Values:
# [1.0120656005570507, 0.000466666666666667, 0.9973196714867746, 0.000466666666666667]
# ------
# 2009.3825502872835
# ******
# [1.0120680463167482, 0.0004627574758325984, 0.9973145039705354, 0.00047179784171324656]
# Dalga Boyu
# 660
# count
# 57
#
# Input Data Values:
# [1.0127363461387955, 0.000466666666666667, 0.9968444094271399, 0.000466666666666667]
# ------
# 2009.5452297518227
# ******
# [1.0127350192658022, 0.0004580435072586063, 0.9968102104860209, 0.0004520551876002316]
# Dalga Boyu
# 665
# count
# 58
#
# Input Data Values:
# [1.0132375370172044, 0.000466666666666667, 0.9960567883881173, 0.000466666666666667]
# ------
# 2009.2847628063184
# ******
# [1.013229181438613, 0.0004909879580280729, 0.9960555813677047, 0.0004873358832678628]
# Dalga Boyu
# 670
# count
# 59
#
# Input Data Values:
# [1.0139440855322062, 0.000466666666666667, 0.9959176657830007, 0.000466666666666667]
# ------
# 2009.8839245994498
# ******
# [1.0139646596219036, 0.00044944802748128957, 0.9959192649775468, 0.0004703411282847736]
# Dalga Boyu
# 675
# count
# 60
#
# Input Data Values:
# [1.0141336333856397, 0.000466666666666667, 0.9949537967011467, 0.000466666666666667]
# ------
# 2009.0839902871355
# ******
# [1.014126483671354, 0.0004655474345973729, 0.9949575066157805, 0.0004861711270434316]
# Dalga Boyu
# 680
# count
# 61
#
# Input Data Values:
# [1.014747856055199, 0.000466666666666667, 0.9954411310665278, 0.000466666666666667]
# ------
# 2010.188621651117
# ******
# [1.0147484515774623, 0.0004620734347758229, 0.9954401700736533, 0.00047822931539648605]
# Dalga Boyu
# 685
# count
# 62
#
# Input Data Values:
# [1.015076685269171, 0.000466666666666667, 0.9947184447723716, 0.000466666666666667]
# ------
# 2009.8158115348867
# ******
# [1.0150938739347963, 0.0004662913536593757, 0.9947219376000896, 0.0004827010561575969]
# Dalga Boyu
# 690
# count
# 63
#
# Input Data Values:
# [1.0152067146788815, 0.000466666666666667, 0.9939968791846847, 0.000466666666666667]
# ------
# 2009.1759169293182
# ******
# [1.0151868440243932, 0.0004485711050206805, 0.9939890729049243, 0.00047419006609792806]
# Dalga Boyu
# 695
# count
# 64
#
# Input Data Values:
# [1.0160015047844047, 0.000466666666666667, 0.9944555697460747, 0.000466666666666667]
# ------
# 2010.4608726668996
# ******
# [1.0159812475678813, 0.0004608927002797354, 0.9944796250990178, 0.00043774411603814004]
# Dalga Boyu
# 700
# count
# 65
#
# Input Data Values:
# [1.0163237864244348, 0.000466666666666667, 0.9882151868650603, 0.000466666666666667]
# ------
# 2004.5299423473432
# ******
# [1.0163302630058397, 0.00047200977563936785, 0.988199679341505, 0.00047256168929895285]
# Dalga Boyu
# 705
# count
# 66
#
# Input Data Values:
# [1.0165345982819016, 0.000466666666666667, 0.9926235044195916, 0.000466666666666667]
# ------
# 2009.1487956209396
# ******
# [1.0165140368508143, 0.00045213592661833273, 0.9926347587701247, 0.0004669306333813559]
# Dalga Boyu
# 710
# count
# 67
#
# Input Data Values:
# [1.0168570076157535, 0.000466666666666667, 0.9921294040588925, 0.000466666666666667]
# ------
# 2008.9922312432325
# ******
# [1.0168496681423698, 0.00045952358282325145, 0.9921425631008614, 0.00046997787440251307]
# Dalga Boyu
# 715
# count
# 68
#
# Input Data Values:
# [1.0170735708665317, 0.000466666666666667, 0.9913514539815539, 0.000466666666666667]
# ------
# 2008.4532833659994
# ******
# [1.0171026942232007, 0.0004470391466989078, 0.9913505891427966, 0.0004497857023011344]
# Dalga Boyu
# 720
# count
# 69
#
# Input Data Values:
# [1.0171189563146656, 0.000466666666666667, 0.9906728474303601, 0.000466666666666667]
# ------
# 2007.7899894634488
# ******
# [1.0171182974695867, 0.0004997244062552036, 0.9906716919938637, 0.00048277175011725987]
# Dalga Boyu
# 725
# count
# 70
#
# Input Data Values:
# [1.0175497744487838, 0.000466666666666667, 0.9908765671936902, 0.000466666666666667]
# ------
# 2008.4113890920423
# ******
# [1.0175558661603137, 0.0004511889560540907, 0.9908555229317262, 0.0004727432013120059]
# Dalga Boyu
# 730
# count
# 71
#
# Input Data Values:
# [1.017255884697552, 0.000466666666666667, 0.989339409616745, 0.000466666666666667]
# ------
# 2006.5962746999317
# ******
# [1.017246858345643, 0.0004443903556623806, 0.9893494163542873, 0.00046924686285044527]
# Dalga Boyu
# 735
# count
# 72
#
# Input Data Values:
# [1.0171132527406264, 0.000466666666666667, 0.98982324511882, 0.000466666666666667]
# ------
# 2006.9646636166103
# ******
# [1.0171235823355562, 0.00048065525315270585, 0.9898410812810535, 0.00044538150934282574]
# Dalga Boyu
# 740
# count
# 73
#
# Input Data Values:
# [1.0176157356655515, 0.000466666666666667, 0.990618053046774, 0.000466666666666667]
# ------
# 2008.1684146339253
# ******
# [1.017590573814892, 0.00046583511399395967, 0.990577840819032, 0.0004591327964610122]
# Dalga Boyu
# 745
# count
# 74
#
# Input Data Values:
# [1.0173023746261638, 0.000466666666666667, 0.9888894443015437, 0.000466666666666667]
# ------
# 2006.185398029958
# ******
# [1.0172922351420348, 0.00047369441131158644, 0.9888931628879223, 0.000477693986129663]
# Dalga Boyu
# 750
# count
# 75
#
# Input Data Values:
# [1.0168887468803673, 0.000466666666666667, 0.9891611524293766, 0.000466666666666667]
# ------
# 2006.029543308515
# ******
# [1.016890637039864, 0.0004642688660017042, 0.9891389062686498, 0.0004733109594349031]
# Dalga Boyu
# 755
# count
# 76
#
# Input Data Values:
# [1.0174826022341776, 0.000466666666666667, 0.9907515201498358, 0.000466666666666667]
# ------
# 2008.2467433281226
# ******
# [1.0174761414265883, 0.00046052709847037255, 0.9907706019015337, 0.0004877111857411007]
# Dalga Boyu
# 760
# count
# 77
#
# Input Data Values:
# [1.0139556737217579, 0.000466666666666667, 0.985322414624431, 0.000466666666666667]
# ------
# 1999.2926062627448
# ******
# [1.0139765011199602, 0.0004896495795527507, 0.9853161051427851, 0.00047394239835014517]
# Dalga Boyu
# 765
# count
# 78
#
# Input Data Values:
# [1.0160712106915986, 0.000466666666666667, 0.995932512864865, 0.000466666666666667]
# ------
# 2011.998511333338
# ******
# [1.0160611632054095, 0.0004696698675146763, 0.9959373481279303, 0.0004498230788509788]
# Dalga Boyu
# 770
# count
# 79
#
# Input Data Values:
# [1.0192164443542593, 0.000466666666666667, 0.9944953584311964, 0.000466666666666667]
# ------
# 2013.681834411937
# ******
# [1.0192018352621015, 0.00046903428690729437, 0.9944799991498342, 0.00046226235510723465]
# Dalga Boyu
# 775
# count
# 80
#
# Input Data Values:
# [1.0138377369191856, 0.000466666666666667, 0.9802247844800214, 0.000466666666666667]
# ------
# 1994.053389423235
# ******
# [1.0138354663643303, 0.00044262998122510333, 0.980217923058905, 0.0004650958213318348]
# Dalga Boyu
# 780
# count
# 81
#
# Input Data Values:
# [1.0, 0.000466666666666667, 0.9798329069069182, 0.000466666666666667]
# ------
# 1979.8412762438825
# ******
# [1.0000007308226353, 0.00047341422501135413, 0.9798405454212482, 0.00048091513717078206]
# Işık Akısının ortalama değeri:
# 1.9798412762438824
# *****
# []
# KorelasyonaArray:(81, 2, 1000)
# TempMatrix:
# [[1.00001701 1.00102596 1.0011741  ... 1.00111372 1.0003593  0.99972092]
#  [0.99494138 0.99553819 0.99492018 ... 0.99558938 0.99519528 0.99532335]
#  [0.98804767 0.98723081 0.98739815 ... 0.98847142 0.98817171 0.98827206]
#  ...
#  [1.01879293 1.01904085 1.01945718 ... 1.01952278 1.01802686 1.01938482]
#  [1.01375906 1.01391291 1.01396104 ... 1.01441797 1.01428431 1.01422587]
#  [0.99977064 0.99993972 1.00017038 ... 0.99970302 1.00035458 1.00045293]]
# Boyut:(81, 1000)
#
# *******
#  1.data'nın Korelasyon Kat sayısı ve görselleştirilmesi:
#
# Korelasyon Kat Sayı Matrisi:
# [[ 1.00000000e+00 -4.91036352e-02  1.64886109e-02 ...  1.84491974e-02
#   -2.71607394e-02  9.35900835e-03]
#  [-4.91036352e-02  1.00000000e+00 -4.62601417e-04 ...  1.95670403e-04
#   -4.51254042e-02 -3.66739686e-02]
#  [ 1.64886109e-02 -4.62601417e-04  1.00000000e+00 ...  3.51782133e-02
#    1.34780634e-02  3.44929122e-02]
#  ...
#  [ 1.84491974e-02  1.95670403e-04  3.51782133e-02 ...  1.00000000e+00
#    4.35050975e-02 -2.40339104e-02]
#  [-2.71607394e-02 -4.51254042e-02  1.34780634e-02 ...  4.35050975e-02
#    1.00000000e+00 -5.84048144e-02]
#  [ 9.35900835e-03 -3.66739686e-02  3.44929122e-02 ... -2.40339104e-02
#   -5.84048144e-02  1.00000000e+00]]
# Boyut:(81, 81)
# TempMatrix:
# [[0.9997851  1.00022402 0.99989351 ... 0.99951019 1.00013924 0.99993412]
#  [0.9936689  0.99528114 0.99390184 ... 0.99481696 0.9945338  0.99390583]
#  [0.99017599 0.99176219 0.99068465 ... 0.99046042 0.99085689 0.98983096]
#  ...
#  [0.99483172 0.9944629  0.99453362 ... 0.99488996 0.99431883 0.99546426]
#  [0.97993224 0.98017663 0.98143616 ... 0.9801761  0.98011237 0.98051418]
#  [0.97910525 0.98000125 0.97955831 ... 0.97933923 0.97999075 0.98027532]]
# Boyut:(81, 1000)
#
# *******
#  2.data'nın Korelasyon Kat sayısı ve görselleştirilmesi:
#
# Korelasyon Kat Sayı Matrisi:
# [[ 1.          0.02891911 -0.05454512 ...  0.0488434  -0.0219613
#   -0.01426413]
#  [ 0.02891911  1.         -0.07829779 ... -0.00736759 -0.00350092
#   -0.04136902]
#  [-0.05454512 -0.07829779  1.         ... -0.03284659  0.02203488
#    0.0078966 ]
#  ...
#  [ 0.0488434  -0.00736759 -0.03284659 ...  1.          0.00189367
#    0.00808131]
#  [-0.0219613  -0.00350092  0.02203488 ...  0.00189367  1.
#    0.03241253]
#  [-0.01426413 -0.04136902  0.0078966  ...  0.00808131  0.03241253
#    1.        ]]
# Boyut:(81, 81)
# Sonuçlar Matrix:
# [[1.99980212 2.00124998 2.0010676  ... 2.00062391 2.00049854 1.99965503]
#  [1.98861028 1.99081934 1.98882202 ... 1.99040634 1.98972908 1.98922918]
#  [1.97822366 1.97899299 1.97808281 ... 1.97893184 1.9790286  1.97810302]
#  ...
#  [2.01362465 2.01350375 2.0139908  ... 2.01441274 2.0123457  2.01484909]
#  [1.9936913  1.99408955 1.9953972  ... 1.99459407 1.99439668 1.99474006]
#  [1.97887589 1.97994097 1.97972869 ... 1.97904225 1.98034533 1.98072825]]
# Boyut:(81, 1000)
#
# Sonuçlar Korelasyon Kat Sayılar Matrisi:
# [[ 1.         -0.00281146  0.00348321 ...  0.02692637 -0.05208003
#   -0.0169383 ]
#  [-0.00281146  1.         -0.03764642 ...  0.04153824 -0.03291669
#   -0.02578292]
#  [ 0.00348321 -0.03764642  1.         ... -0.02209831  0.01373315
#    0.01305404]
#  ...
#  [ 0.02692637  0.04153824 -0.02209831 ...  1.          0.05318406
#   -0.00673864]
#  [-0.05208003 -0.03291669  0.01373315 ...  0.05318406  1.
#   -0.01477697]
#  [-0.0169383  -0.02578292  0.01305404 ... -0.00673864 -0.01477697
#    1.        ]]
# Boyut:(81, 81)
